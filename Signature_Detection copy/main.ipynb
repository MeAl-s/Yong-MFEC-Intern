# %%
import os
import cv2

# Function to check and convert image to JPEG
def check_and_convert_image(image_path, output_path):
    # Check if the image is already a JPEG
    if not image_path.lower().endswith('.jpg') and not image_path.lower().endswith('.jpeg'):
        # Read the original image
        image = cv2.imread(image_path)
        # Convert and save the image as a high-quality JPEG
        cv2.imwrite(output_path, image, [int(cv2.IMWRITE_JPEG_QUALITY), 95])
        print(f"Converted {image_path} to {output_path}")
        return output_path
    else:
        print(f"Image {image_path} is already a JPEG")
        return image_path

# Paths
image_path = r"C:\Users\ACER\Downloads\Yong-MFEC-Intern\Signature_Detection\data\firstdataset.png"
jpeg_image_path = r"C:\Users\ACER\Downloads\Yong-MFEC-Intern\Signature_Detection\firstdataset.png"
annotated_image_path = r'C:\Users\ACER\Downloads\Yong-MFEC-Intern\Signature_Detection\firstdataset.png'
phrases_path = r"C:\\Users\\ACER\\Downloads\\Yong-MFEC-Intern\\Signature_Detection\\identified_phrases.jsonl"


# Check and convert image if necessary
final_image_path = check_and_convert_image(image_path, jpeg_image_path)
# Out:
# Converted C:\Users\ACER\Downloads\Yong-MFEC-Intern\Signature_Detection\data\firstdataset.png to C:\Users\ACER\Downloads\Yong-MFEC-Intern\Signature_Detection\firstdataset.png

# %%
# Enhance image quality for better OCR results
def enhance_image(image_path, output_path):
    # Read the image
    image = cv2.imread(image_path)
    print(image.shape)
    if image is None:
        raise FileNotFoundError(f"Unable to read image at {enhanced_image_path}")
    
    # Convert to grayscale
    gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
    
    # Apply GaussianBlur to reduce noise and improve text detection
    blurred_image = cv2.GaussianBlur(gray_image, (5, 5), 0)
    
    # Apply adaptive thresholding to enhance the text regions
    thresh_image = cv2.adaptiveThreshold(blurred_image, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C, cv2.THRESH_BINARY, 11, 2)
    
    # Save the enhanced image
    cv2.imwrite(output_path, thresh_image)
    print(f"Enhanced image saved at {output_path}")

# Paths
enhanced_image_path = r"C:\\Users\ACER\Downloads\\Yong-MFEC-Intern\\Signature_Detection\\firstdataset.jpg"

# Enhance the image
enhance_image(final_image_path, enhanced_image_path)
# Out:
# (1800, 1272, 3)
# Enhanced image saved at C:\\Users\ACER\Downloads\\Yong-MFEC-Intern\\Signature_Detection\\firstdataset.jpg

# %%
import os
from google.cloud import vision
import google.cloud
import cv2

# Set up the environment variable for Google Cloud authentication
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "C:\\Users\\ACER\\Downloads\\Yong-MFEC-Intern\\Signature_Detection\\signature-429903-456702e081c7.json"

# Initialize the Google Cloud Vision client
client = vision.ImageAnnotatorClient()

def detect_text(image_path):
    with open(image_path, "rb") as image_file:
        content = image_file.read()

    image = vision.Image(content=content)
    response = client.text_detection(image=image)
    texts = response.text_annotations

    if response.error.message:
        raise Exception(f'{response.error.message}')

    return texts

# Example usage
texts = detect_text(enhanced_image_path)
for text in texts:
    print(text.description)
    # Open a file in write mode
with open('extracted_texts.txt', 'w', encoding='utf-8') as file:
    # Iterate through each text annotation and write the description to the file
    for text in texts:
        file.write(text.description + "\n")

print("Text has been written to extracted_texts.txt")
# Out:
# แบบคําขอมีบัตรแสดงตนเจ้าหน้าที่กรมการแพทย์ / นำรถยนต์เข้าจอดในพื้นที่กรมการแพทย์
# เขียนที่
# พ.ศ...............
# ข้าพเจ้าชื่อ-นามสกุล (ภาษาไทย)
# ชื่อ-นามสกุล (ภาษาอังกฤษ.........
# หน่วยงาน....
# มีความประสงค์ขอมีบัตรแสดงตนเจ้าหน้าที่กรมการแพทย์ / ขออนุญาตนำรถยนต์เข้าจอดในพื้นที่กรมการแพทย์
# กรณี
# 1. ขอมีบัตรครั้งแรก
# 2. ขอมีบัตรใหม่ เนื่องจากบัตรหาย / ถูกทำลาย / ชำรุด
# 3. ขออนุญาตนำรถยนต์เข้าจอดในพื้นที่กรมการแพทย์ (แนบสำเนาทะเบียนรถ)
# ที่อยู่ปัจจุบัน (สามารถติดต่อได้สะดวก)
# บ้านเลขที่
# .หมู่.
# แขวง/ตําบล...
# ....ตรอก/ซอย
# เขต/อำเภอ
# จังหวัด.................
# รหัสไปรษณีย์
# โทรศัพท์ที่ทํางาน..
# ...โทรศัพท์มือถือ..
# ลงชื่อ
# ผู้ขอสิทธิ์ในการถือบัตรฯ
# .)
# ลงชื่อ
# ผู้อำนวยการสำนัก/กลุ่ม
# ลงชื่อ
# ผู้อนุมัติ
# .)
# เลขานุการกรมการแพทย์
# ปี ผู้รับบัตรทราบสิทธิ์และข้อควรปฏิบัติในการถือบัตรแล้ว หมายเลขบัตร
# ลงชื่อ
# ผู้รับบัตร
# ลงชื่อ
# >
# ผู้จ่ายบัตร
# แบบ
# คํา
# ขอ
# มี
# บัตร
# แสดง
# ตน
# เจ้าหน้าที่
# กรมการ
# แพทย์
# /
# นำ
# รถยนต์
# เข้า
# จอด
# ใน
# พื้นที่
# กรมการ
# แพทย์
# เขียน
# ที่
# พ
# .
# ศ
# ...............
# ข้าพเจ้า
# ชื่อ
# -
# นามสกุล
# (
# ภาษา
# ไทย
# )
# ชื่อ
# -
# นามสกุล
# (
# ภาษา
# อังกฤษ
# .........
# หน่วย
# งาน
# ....
# มี
# ความ
# ประสงค์
# ขอ
# มี
# บัตร
# แสดง
# ตน
# เจ้าหน้าที่
# กรมการ
# แพทย์
# /
# ขอ
# อนุญาต
# นำ
# รถยนต์
# เข้า
# จอด
# ใน
# พื้นที่
# กรมการ
# แพทย์
# กรณี
# 1.
# ขอ
# มี
# บัตร
# ครั้ง
# แรก
# 2.
# ขอ
# มี
# บัตร
# ใหม่
# เนื่องจาก
# บัตร
# หาย
# /
# ถูก
# ทำลาย
# /
# ชำรุด
# 3.
# ขอ
# อนุญาต
# นำ
# รถยนต์
# เข้า
# จอด
# ใน
# พื้นที่
# กรมการ
# แพทย์
# (
# แนบ
# สำเนา
# ทะเบียน
# รถ
# )
# ที่
# อยู่
# ปัจจุบัน
# (
# สามารถ
# ติดต่อ
# ได้
# สะดวก
# )
# บ้าน
# เลข
# ที่
# .
# หมู่
# .
# แขวง
# /
# ตํา
# บ
# ล
# ...
# ....
# ตรอก
# /
# ซอย
# เขต
# /
# อำเภอ
# จังหวัด
# .................
# รหัส
# ไปรษณีย์
# โทรศัพท์
# ที่
# ทํา
# งาน
# ..
# ...
# โทรศัพท์
# มือ
# ถือ
# ..
# ลงชื่อ
# ผู้
# ขอ
# สิทธิ์
# ใน
# การ
# ถือ
# บัตร
# ฯ
# .
# )
# ลงชื่อ
# ผู้
# อำนวย
# การ
# สำนัก
# /
# กลุ่ม
# ลงชื่อ
# ผู้
# อนุมัติ
# .
# )
# เลขานุการ
# กรมการ
# แพทย์
# ปี
# ผู้รับ
# บัตร
# ทราบ
# สิทธิ์
# และ
# ข้อ
# ควร
# ปฏิบัติ
# ใน
# การ
# ถือ
# บัตร
# แล้ว
# หมายเลข
# บัตร
# ลงชื่อ
# ผู้รับ
# บัตร
# ลงชื่อ
# >
# ผู้
# จ่าย
# บัตร
# Text has been written to extracted_texts.txt

# %%
import os
import numpy as np
from openai import AzureOpenAI

# Azure OpenAI Configuration
os.environ["OPENAI_API_TYPE"] = "azure"
os.environ["OPENAI_API_VERSION"] = "2023-05-15"
os.environ["AZURE_OPENAI_ENDPOINT"] = "https://insideout.openai.azure.com/"
os.environ["OPENAI_API_KEY"] = "b6c0397877a9420aa7b3c2bad2e622f7"

client = AzureOpenAI(
    api_version=os.environ["OPENAI_API_VERSION"],
    azure_endpoint=os.environ["AZURE_OPENAI_ENDPOINT"],
    api_key=os.environ["OPENAI_API_KEY"]
)

extracted_text = texts[0].description

# %%
import json

response = client.chat.completions.create(
            model="gpt4o",
            messages=[
                {
                    "role": "system",
                    "content": f"""You are an assistant that helps analyze document text to identify key phrases indicating where signatures are needed, make sure to cover every single possible signature, especially if there're full stops or dot dot lines within the text you analyzed for example the text "...ลงชื่อ" has a ... in it which means that its a place where people can sign. Once you have identified the key phrases make sure they are not only one single characters, they must be a word consisted in the dictionary, they cannot be words that do not make sense, you should only list the key phrases without using numbers, bullet points, or any other form of listing."""
                },
                {
            "role": "user",
            "content": extracted_text
        }
            ]
        )

print("OpenAI Response:", response.choices[0].message.content.strip())

identified_phrases = response.choices[0].message.content.strip()
# Save identified phrases as JSONL
with open("identified_phrases.jsonl", "w", encoding="utf-8") as file:
    json.dump({"phrases": identified_phrases}, file, ensure_ascii=False)
    file.write("\n")
# Out:
# OpenAI Response: ลงชื่อ
# ผู้ขอสิทธิ์ในการถือบัตรฯ
# ลงชื่อ
# ผู้อำนวยการสำนัก/กลุ่ม
# ลงชื่อ
# ผู้อนุมัติ
# ลงชื่อ
# ผู้รับบัตร
# ลงชื่อ
# ผู้จ่ายบัตร

# %%
import re




            
with open(phrases_path, 'r', encoding='utf-8') as file:
    data = json.load(file)
    phrases = data["phrases"].split('\n')

# Clean up phrases to ensure no leading/trailing whitespaces
# Create patterns for the exact words
patterns = [re.compile(re.escape(word)) for word in phrases]


# Compile regex patterns for the phrases
print(patterns)

image = cv2.imread(enhanced_image_path)
# Out:
# [re.compile('ลงชื่อ'), re.compile('ผู้ขอสิทธิ์ในการถือบัตรฯ'), re.compile('ลงชื่อ'), re.compile('ผู้อำนวยการสำนัก/กลุ่ม'), re.compile('ลงชื่อ'), re.compile('ผู้อนุมัติ'), re.compile('ลงชื่อ'), re.compile('ผู้รับบัตร'), re.compile('ลงชื่อ'), re.compile('ผู้จ่ายบัตร')]

# %%
import os
from google.cloud import vision
import cv2
import json
import re
import numpy as np

# Set up the environment variable for Google Cloud authentication
os.environ["GOOGLE_APPLICATION_CREDENTIALS"] = "C:\\Users\\ACER\\Downloads\\Yong-MFEC-Intern\\Signature_Detection\\signature-429903-456702e081c7.json"

# Initialize the Google Cloud Vision client
client = vision.ImageAnnotatorClient()

def detect_words_with_boxes(texts, patterns):
    detected_boxes = []
    for text in texts[1:]:  # Skip the first element as it contains the whole text
        for pattern in patterns:
            if pattern.fullmatch(text.description.strip()):
                vertices = [(vertex.x, vertex.y) for vertex in text.bounding_poly.vertices]
                detected_boxes.append((vertices, text.description))
    return detected_boxes

def draw_tick(image, start_point):
    tick_length = 20
    thickness = 2
    color = (0, 0, 255)  # Red color in BGR

    # Define tick points relative to start_point
    end_point1 = (start_point[0] - int(tick_length / 2), start_point[1] + tick_length)
    end_point2 = (start_point[0] + tick_length, start_point[1] - int(tick_length / 2))

    # Draw tick on the image
    image = cv2.line(image, start_point, end_point1, color, thickness)
    image = cv2.line(image, end_point1, end_point2, color, thickness)

def annotate_image(image_path, detected_boxes, annotated_image_path):
    image = cv2.imread(image_path)
    for (vertices, word) in detected_boxes:
        # Calculate the tick start point as the top-right corner of the bounding box
        top_right = (max(vertex[0] for vertex in vertices), min(vertex[1] for vertex in vertices))
        draw_tick(image, top_right)
    cv2.imwrite(annotated_image_path, image)

# Detect words and their bounding boxes
detected_boxes = detect_words_with_boxes(texts, patterns)

# Annotate and save the image
annotate_image(enhanced_image_path, detected_boxes, annotated_image_path)

print(f"Annotated image saved to {annotated_image_path}")
# Out:
# Annotated image saved to C:\Users\ACER\Downloads\Yong-MFEC-Intern\Signature_Detection\firstdataset.png

# %%
annotated_texts = detect_text(annotated_image_path)
for text in annotated_texts:
    print(text.description)
extracted2_text = annotated_texts[0].description

with open('extracted2_texts.txt', 'w', encoding='utf-8') as file:
    # Iterate through each text annotation and write the description to the filew
    for text in texts:
        file.write(text.description + "\n")
# Out:
# แบบคําขอมีบัตรแสดงตนเจ้าหน้าที่กรมการแพทย์ / นำรถยนต์เข้าจอดในพื้นที่กรมการแพทย์
# เขียนที่
# พ.ศ...............
# ข้าพเจ้าชื่อ-นามสกุล (ภาษาไทย)
# ชื่อ-นามสกุล (ภาษาอังกฤษ.........
# หน่วยงาน....
# มีความประสงค์ขอมีบัตรแสดงตนเจ้าหน้าที่กรมการแพทย์ / ขออนุญาตนำรถยนต์เข้าจอดในพื้นที่กรมการแพทย์
# กรณี
# 1. ขอมีบัตรครั้งแรก
# 2. ขอมีบัตรใหม่ เนื่องจากบัตรหาย / ถูกทำลาย / ชำรุด
# 3. ขออนุญาตนำรถยนต์เข้าจอดในพื้นที่กรมการแพทย์ (แนบสำเนาทะเบียนรถ)
# ที่อยู่ปัจจุบัน (สามารถติดต่อได้สะดวก)
# บ้านเลขที่
# หมู่
# แขวง/ตําบล...
# ....ตรอก/ซอย
# เขต/อำเภอ
# จังหวัด.................
# รหัสไปรษณีย์
# โทรศัพท์ที่ทํางาน..
# โทรศัพท์มือถือ..
# ลงชื่อ
# ผู้ขอสิทธิ์ในการถือบัตรฯ
# .)
# ลงชื่อ
# ลงชื่อ
# เลขานุการกรมการแพทย์
# ปี ผู้รับบัตรทราบสิทธิ์และข้อควรปฏิบัติในการถือบัตรแล้ว หมายเลขบัตร
# ลงชื่อ
# ผู้รับบัตร
# ลงชื่อ
# >
# ผู้อำนวยการสำนัก/กลุ่ม
# ผู้อนุมัติ
# .)
# ผู้จ่ายบัตร
# แบบ
# คํา
# ขอ
# มี
# บัตร
# แสดง
# ตน
# เจ้าหน้าที่
# กรมการ
# แพทย์
# /
# นำ
# รถยนต์
# เข้า
# จอด
# ใน
# พื้นที่
# กรมการ
# แพทย์
# เขียน
# ที่
# พ
# .
# ศ
# ...............
# ข้าพเจ้า
# ชื่อ
# -
# นามสกุล
# (
# ภาษา
# ไทย
# )
# ชื่อ
# -
# นามสกุล
# (
# ภาษา
# อังกฤษ
# .........
# หน่วย
# งาน
# ....
# มี
# ความ
# ประสงค์
# ขอ
# มี
# บัตร
# แสดง
# ตน
# เจ้าหน้าที่
# กรมการ
# แพทย์
# /
# ขอ
# อนุญาต
# นำ
# รถยนต์
# เข้า
# จอด
# ใน
# พื้นที่
# กรมการ
# แพทย์
# กรณี
# 1.
# ขอ
# มี
# บัตร
# ครั้ง
# แรก
# 2.
# ขอ
# มี
# บัตร
# ใหม่
# เนื่องจาก
# บัตร
# หาย
# /
# ถูก
# ทำลาย
# /
# ชำรุด
# 3.
# ขอ
# อนุญาต
# นำ
# รถยนต์
# เข้า
# จอด
# ใน
# พื้นที่
# กรมการ
# แพทย์
# (
# แนบ
# สำเนา
# ทะเบียน
# รถ
# )
# ที่
# อยู่
# ปัจจุบัน
# (
# สามารถ
# ติดต่อ
# ได้
# สะดวก
# )
# บ้าน
# เลข
# ที่
# หมู่
# แขวง
# /
# ตํา
# บ
# ล
# ...
# ....
# ตรอก
# /
# ซอย
# เขต
# /
# อำเภอ
# จังหวัด
# .................
# รหัส
# ไปรษณีย์
# โทรศัพท์
# ที่
# ทํา
# งาน
# ..
# โทรศัพท์
# มือ
# ถือ
# ..
# ลงชื่อ
# ผู้
# ขอ
# สิทธิ์
# ใน
# การ
# ถือ
# บัตร
# ฯ
# .
# )
# ลงชื่อ
# ลงชื่อ
# เลขานุการ
# กรมการ
# แพทย์
# ปี
# ผู้รับ
# บัตร
# ทราบ
# สิทธิ์
# และ
# ข้อ
# ควร
# ปฏิบัติ
# ใน
# การ
# ถือ
# บัตร
# แล้ว
# หมายเลข
# บัตร
# ลงชื่อ
# ผู้รับ
# บัตร
# ลงชื่อ
# >
# ผู้
# อำนวย
# การ
# สำนัก
# /
# กลุ่ม
# ผู้
# อนุมัติ
# .
# )
# ผู้
# จ่าย
# บัตร
