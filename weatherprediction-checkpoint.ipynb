# %%
import pandas as pd

weather = pd.read_csv("C:\\Users\\ACER\\Documents\\MFEC\\Weather Prediction\\seattle-weather.csv", index_col = "date")

# %%
weather
# Out:
#             precipitation  temp_max  temp_min  wind  weather
# date
# 2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 2012-01-02           10.9      10.6       2.8   4.5     rain
# 2012-01-03            0.8      11.7       7.2   2.3     rain
# 2012-01-04           20.3      12.2       5.6   4.7     rain
# 2012-01-05            1.3       8.9       2.8   6.1     rain
# ...                   ...       ...       ...   ...      ...
# 2015-12-27            8.6       4.4       1.7   2.9     rain
# 2015-12-28            1.5       5.0       1.7   1.3     rain
# 2015-12-29            0.0       7.2       0.6   2.6      fog
# 2015-12-30            0.0       5.6      -1.0   3.4      sun
# 2015-12-31            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 5 columns]

# %%
weather.loc["2012-01-01",:]
# Out:
# precipitation        0.0
# temp_max            12.8
# temp_min             5.0
# wind                 4.7
# weather          drizzle
# Name: 2012-01-01, dtype: object

# %%
weather.apply(pd.isnull).sum()
# Out:
# precipitation    0
# temp_max         0
# temp_min         0
# wind             0
# weather          0
# dtype: int64

# %%
del weather["wind"]
del weather["weather"]

# %%
weather
# Out:
#             precipitation  temp_max  temp_min
# date
# 2012-01-01            0.0      12.8       5.0
# 2012-01-02           10.9      10.6       2.8
# 2012-01-03            0.8      11.7       7.2
# 2012-01-04           20.3      12.2       5.6
# 2012-01-05            1.3       8.9       2.8
# ...                   ...       ...       ...
# 2015-12-27            8.6       4.4       1.7
# 2015-12-28            1.5       5.0       1.7
# 2015-12-29            0.0       7.2       0.6
# 2015-12-30            0.0       5.6      -1.0
# 2015-12-31            0.0       5.6      -2.1
#
# [1461 rows x 3 columns]

# %%
weather.dtypes
# Out:
# precipitation    float64
# temp_max         float64
# temp_min         float64
# dtype: object

# %%
weather[["temp_max","temp_min"]].plot()

# %%
weather["precipitation"].plot()

# %%
weather["target"] = weather.shift(-1)["precipitation"]

# %%
weather
# Out:
#             precipitation  temp_max  temp_min  target
# date
# 2012-01-01            0.0      12.8       5.0    10.9
# 2012-01-02           10.9      10.6       2.8     0.8
# 2012-01-03            0.8      11.7       7.2    20.3
# 2012-01-04           20.3      12.2       5.6     1.3
# 2012-01-05            1.3       8.9       2.8     2.5
# ...                   ...       ...       ...     ...
# 2015-12-27            8.6       4.4       1.7     1.5
# 2015-12-28            1.5       5.0       1.7     0.0
# 2015-12-29            0.0       7.2       0.6     0.0
# 2015-12-30            0.0       5.6      -1.0     0.0
# 2015-12-31            0.0       5.6      -2.1     NaN
#
# [1461 rows x 4 columns]

# %%
weather = weather.iloc[:-1, :].copy()

# %%
weather
# Out:
#             precipitation  temp_max  temp_min  target
# date
# 2012-01-01            0.0      12.8       5.0    10.9
# 2012-01-02           10.9      10.6       2.8     0.8
# 2012-01-03            0.8      11.7       7.2    20.3
# 2012-01-04           20.3      12.2       5.6     1.3
# 2012-01-05            1.3       8.9       2.8     2.5
# ...                   ...       ...       ...     ...
# 2015-12-26            0.0       4.4       0.0     8.6
# 2015-12-27            8.6       4.4       1.7     1.5
# 2015-12-28            1.5       5.0       1.7     0.0
# 2015-12-29            0.0       7.2       0.6     0.0
# 2015-12-30            0.0       5.6      -1.0     0.0
#
# [1460 rows x 4 columns]

# %%
from sklearn.linear_model import Ridge

reg = Ridge(alpha=.1)

# %%
predictors = ["precipitation", "temp_max", "temp_min"]

# %%
train = weather.loc[:"2015-06-30"]
test = weather.loc["2015-07-01":]

# %%
reg.fit(train[predictors], train["target"])
# Out:
# Ridge(alpha=0.1)

# %%
predictions = reg.predict(test[predictors])

# %%
from sklearn.metrics import mean_absolute_error 

mean_absolute_error(test["target"], predictions)
# Out:
# 4.372670454004365

# %%
combined = pd.concat([test["target"], pd.Series(predictions, index = test.index)], axis = 1)
combined_columns = ["actual", "predictions"]

# %%
combined.plot()

# %%
reg.coef_
# Out:
# array([ 0.20209187, -0.34693026,  0.35403237])
